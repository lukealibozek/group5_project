# %%
import requests
import pandas as pd
import json

# %%
url = "https://data.cdc.gov/resource/n8mc-b4w4"

# %%
response = requests.get(url).json()

# %%
df = pd.DataFrame(response)

# %%
df.describe()
# Out:
#        case_month res_state state_fips_code res_county county_fips_code  \
# count        1000      1000            1000       1000             1000
# unique         21        19              19         49               52
# top       2022-01        CA              06    SUFFOLK            39035
# freq          298       209             209         38               20
#
#              age_group     sex   race            ethnicity  \
# count             1000    1000   1000                 1000
# unique               4       3      7                    4
# top     18 to 49 years  Female  White  Non-Hispanic/Latino
# freq               481     640    476                  507
#
#        case_onset_interval  process exposure_yn             current_status  \
# count                  323     1000        1000                       1000
# unique                   2        4           3                          2
# top                      0  Missing     Missing  Laboratory-confirmed case
# ...

# %% [markdown]
# The API only provides 1000 rows. Full CSV to be downloaded.
