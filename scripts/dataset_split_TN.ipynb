# %%
import pandas as pd
import requests

# %%
df = pd.read_csv('data/COVID-19_Case_Surveillance_Public_Use_Data_with_Geography.csv', low_memory=False)
df.head()
# Out:
#   case_month res_state  state_fips_code   res_county  county_fips_code  \
# 0    2021-12        CA              6.0    SAN DIEGO            6073.0
# 1    2022-01        NY             36.0  WESTCHESTER           36119.0
# 2    2020-10        MN             27.0     HENNEPIN           27053.0
# 3    2021-01        NV             32.0        CLARK           32003.0
# 4    2022-02        AZ              4.0         PIMA            4019.0
#
#         age_group     sex     race            ethnicity  \
# 0  18 to 49 years    Male    Black  Non-Hispanic/Latino
# 1       65+ years    Male      NaN                  NaN
# 2  18 to 49 years  Female    White  Non-Hispanic/Latino
# 3  18 to 49 years  Female  Unknown              Unknown
# 4  50 to 64 years  Female    White  Non-Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval               process  \
# 0                              NaN                  NaN               Missing
# 1                              NaN                  NaN               Missing
# 2                              0.0                  NaN               Missing
# 3                              0.0                  NaN  Routine surveillance
# 4                              NaN                  NaN               Missing
#
#   exposure_yn             current_status symptom_status  hosp_yn   icu_yn  \
# 0     Missing  Laboratory-confirmed case        Unknown  Missing  Missing
# 1     Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 2     Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 3     Missing  Laboratory-confirmed case        Missing  Unknown  Unknown
# 4     Missing  Laboratory-confirmed case        Missing  Missing  Missing
#
#   death_yn underlying_conditions_yn
# 0  Missing                      NaN
# 1       No                      NaN
# 2       No                      NaN
# 3       No                      NaN
# 4  Missing                      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69664983 entries, 0 to 69664982
# Data columns (total 19 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   case_month                       object
#  1   res_state                        object
#  2   state_fips_code                  float64
#  3   res_county                       object
#  4   county_fips_code                 float64
#  5   age_group                        object
#  6   sex                              object
#  7   race                             object
#  8   ethnicity                        object
#  9   case_positive_specimen_interval  float64
#  10  case_onset_interval              float64
#  11  process                          object
#  12  exposure_yn                      object
#  13  current_status                   object
#  14  symptom_status                   object
#  15  hosp_yn                          object
#  16  icu_yn                           object
#  17  death_yn                         object
#  18  underlying_conditions_yn         object
# dtypes: float64(4), object(15)
# memory usage: 9.9+ GB

# %%
tn_df = df[df['res_state'] == "TN"]
tn_df.head()
# Out:
#     case_month res_state  state_fips_code res_county  county_fips_code  \
# 43     2020-11        TN             47.0     SHELBY           47157.0
# 52     2021-01        TN             47.0   DAVIDSON           47037.0
# 98     2020-11        TN             47.0     SHELBY           47157.0
# 108    2021-01        TN             47.0   DAVIDSON           47037.0
# 154    2020-11        TN             47.0     SHELBY           47157.0
#
#           age_group     sex   race            ethnicity  \
# 43   50 to 64 years  Female  White  Non-Hispanic/Latino
# 52        65+ years    Male  White              Missing
# 98   50 to 64 years  Female  White  Non-Hispanic/Latino
# 108       65+ years    Male  White              Missing
# 154  50 to 64 years  Female  White  Non-Hispanic/Latino
#
#      case_positive_specimen_interval  case_onset_interval  process  \
# 43                               0.0                  NaN  Missing
# 52                               0.0                  NaN  Missing
# 98                               0.0                  NaN  Missing
# 108                              0.0                  NaN  Missing
# 154                              0.0                  0.0  Missing
#
#     exposure_yn             current_status symptom_status  hosp_yn   icu_yn  \
# 43      Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 52      Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 98      Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 108     Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 154     Missing              Probable Case    Symptomatic  Missing  Missing
#
#     death_yn underlying_conditions_yn
# 43   Missing                      NaN
# 52   Missing                      NaN
# 98   Missing                      NaN
# 108  Missing                      NaN
# 154  Missing                      NaN

# %%
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1992915 entries, 43 to 69664981
# Data columns (total 19 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   case_month                       object
#  1   res_state                        object
#  2   state_fips_code                  float64
#  3   res_county                       object
#  4   county_fips_code                 float64
#  5   age_group                        object
#  6   sex                              object
#  7   race                             object
#  8   ethnicity                        object
#  9   case_positive_specimen_interval  float64
#  10  case_onset_interval              float64
#  11  process                          object
#  12  exposure_yn                      object
#  13  current_status                   object
#  14  symptom_status                   object
#  15  hosp_yn                          object
#  16  icu_yn                           object
#  17  death_yn                         object
#  18  underlying_conditions_yn         object
# dtypes: float64(4), object(15)
# memory usage: 304.1+ MB

# %%
tn_df.to_csv("data/cdc_COVID_TN.csv")
